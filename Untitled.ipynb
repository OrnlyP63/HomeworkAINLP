# %%
import re
import pandas as pd
import bs4
import requests
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

from spacy.matcher import Matcher 
from spacy.tokens import Span 

import networkx as nx

import matplotlib.pyplot as plt
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline

# %%
doc = nlp("the drawdown process is governed by astm standard d823")

for tok in doc:
    print(tok.text, "...", tok.dep_)
# Out:
# the ... det
# drawdown ... compound
# process ... nsubjpass
# is ... auxpass
# governed ... ROOT
# by ... agent
# astm ... compound
# standard ... pobj
# d823 ... punct

# %%
df = pd.read_csv('wiki\wikisent2.txt', delimiter = "\t",header=None)

# %%
df.head()
# Out:
#                                                                                                                                                                                                          0
# 0                                                                                                                                        0.000123, which corresponds to a distance of 705 Mly, or 216 Mpc.
# 1                                                                                                                                         000webhost is a free web hosting service, operated by Hostinger.
# 2                                                                                                                           0010x0010 is a Dutch-born audiovisual artist, currently living in Los Angeles.
# ...

# %%
def get_entities(sent):
    ## chunk 1
    ent1 = ""
    ent2 = ""

    prv_tok_dep = ""    # dependency tag of previous token in the sentence
    prv_tok_text = ""   # previous token in the sentence

    prefix = ""
    modifier = ""

    #############################################################
    for tok in nlp(sent):
        ## chunk 2
        # if token is a punctuation mark then move on to the next token
        if tok.dep_ != "punct":
            # check: token is a compound word or not
            if tok.dep_ == "compound":
                prefix = tok.text
                # if the previous word was also a 'compound' then add the current word to it
                if prv_tok_dep == "compound":
                    prefix = prv_tok_text + " "+ tok.text

            # check: token is a modifier or not
            if tok.dep_.endswith("mod") == True:
                modifier = tok.text
                # if the previous word was also a 'compound' then add the current word to it
                if prv_tok_dep == "compound":
                    modifier = prv_tok_text + " "+ tok.text

            ## chunk 3
            if tok.dep_.find("subj") == True:
                ent1 = modifier +" "+ prefix + " "+ tok.text
                prefix = ""
                modifier = ""
                prv_tok_dep = ""
                prv_tok_text = ""      

            ## chunk 4
            if tok.dep_.find("obj") == True:
                ent2 = modifier +" "+ prefix +" "+ tok.text

            ## chunk 5  
            # update variables
            prv_tok_dep = tok.dep_
            prv_tok_text = tok.text
            #############################################################

    return [ent1.strip(), ent2.strip()]

# %%
get_entities("I love my cat")
# Out:
# ['I', 'cat']

# %%
df[0].sample(5)
# Out:
# 1491912                                                                             Fixedsys fonts of different code pages have different point sizes.
# 3650740                                                   Jonathan London (born December 5, 1978) is an American director, screenwriter, and producer.
# 5266900                                                                                                  Such technologies remain largely theoretical.
# 3782122    Large portions of White Zombie were shot on the Universal Studios lot, borrowing many props and scenery from other horror films of the era.
# 6646404                                                                      The Rebbe was immediately shot to death on that day, 29 Iyar 5702 (1942).
# Name: 0, dtype: object

# %%
candidate_sentences = df.iloc[:10000,0]

# %%
entity_pairs = []

for i in tqdm(candidate_sentences):
    entity_pairs.append(get_entities(i))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 10000/10000 [02:07<00:00, 78.74it/s]

# %%
def get_relation(sent):

    doc = nlp(sent)

    # Matcher class object 
    matcher = Matcher(nlp.vocab)

    #define the pattern 
    pattern = [[{'DEP':'ROOT'}], 
            [{'DEP':'prep'},{'OP':"?"}],
            [{'DEP':'agent'},{'OP':"?"}],  
            [{'POS':'ADJ'},{'OP':"?"}]] 

    matcher.add("matching_1", pattern) 

    matches = matcher(doc)
    k = len(matches) - 1

    span = doc[matches[k][1]:matches[k][2]] 

    return(span.text)

# %%
get_relation("John completed the task")
# Out:
# 'completed'

# %%
relations = [get_relation(i) for i in tqdm(candidate_sentences)]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 10000/10000 [02:15<00:00, 74.01it/s]

# %%
pd.Series(relations).value_counts()[:50]
# Out:
# of the                   705
# in the                   576
# in diameter              347
# in world                 191
# during the               183
# for the                  140
# in India                 123
# by the                   113
# on November              107
# on the                    92
# presidential election     92
# of Marylebone             92
# competed                  76
# between the               65
# is                        64
# to the                    54
# important match           54
# natural number            52
# at the                    44
# with the                  43
# in New                    42
# as the                    40
# in London                 39
# in England                38
# from the                  36
# in 17                     34
# was                       33
# in World                  30
# in 15                     29
# during World              24
# Australian rules          23
# in this                   23
# ...

# %%
# extract subject
source = [i[0] for i in entity_pairs]

# extract object
target = [i[1] for i in entity_pairs]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})

# %%
kg_df
# Out:
#                           source                            target  \
# 0                          which                          705  Mly
# 1                     000webhost                hosting  Hostinger
# 2                      0010x0010             currently Los Angeles
# 3                              0                0 college students
# 4                           0.01         1996 Fifth Colvmn Records
# ...                          ...                               ...
# 9995                       Carno     1985/86 Amateur League season
# 9996                          84  37th International Hockey League
# 9997             ninth  Division             top flight Elitserien
# 9998  1983 Handball Championship                             Egypt
# 9999     1983 Algerian Cup Final                 21st Algerian Cup
#
#               edge
# 0           of 705
# 1     by Hostinger
# 2           in Los
# 3       in college
# 4         by Fifth
# ...            ...
# ...

# %%
# create a directed-graph from a dataframe
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %%
# plt.figure(figsize=(12,12))

# pos = nx.spring_layout(G)
# nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
# plt.show()

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="in Los"], "source", "target",  edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5) # k regulates the distance between nodes
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="as a"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5)
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
